# %%
pip install "fastapi[standard]"
# Out:
# Collecting fastapi[standard]
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting starlette<0.48.0,>=0.40.0 (from fastapi[standard])
#   Downloading starlette-0.47.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi[standard]) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi[standard]) (4.11.0)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cli-0.0.11-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi[standard]) (0.27.0)
# Collecting jinja2>=3.1.5 (from fastapi[standard])
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting python-multipart>=0.0.18 (from fastapi[standard])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard])
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi[standard]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi[standard]) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from starlette<0.48.0,>=0.40.0->fastapi[standard]) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi[standard]) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi[standard]) (1.3.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard])
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer>=0.15.1 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading typer-0.17.4-py3-none-any.whl.metadata (15 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rich_toolkit-0.15.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cloud_cli-0.1.5-py3-none-any.whl.metadata (3.2 kB)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rignore-0.6.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting sentry-sdk>=2.20.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading sentry_sdk-2.37.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.0->fastapi[standard]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.0->fastapi[standard]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi[standard]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2>=3.1.5->fastapi[standard]) (2.1.3)
# Requirement already satisfied: click>=8.1.7 in /opt/anaconda3/lib/python3.12/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (8.1.7)
# Requirement already satisfied: rich>=13.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (13.7.1)
# Collecting typing-extensions>=4.8.0 (from fastapi[standard])
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (0.1.0)
# Requirement already satisfied: urllib3>=1.26.11 in /opt/anaconda3/lib/python3.12/site-packages (from sentry-sdk>=2.20.0->fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.2.3)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (1.5.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading httptools-0.6.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (1.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (6.0.1)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading uvloop-0.21.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading watchfiles-1.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Downloading fastapi-0.116.1-py3-none-any.whl (95 kB)
# Downloading starlette-0.47.3-py3-none-any.whl (72 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading fastapi_cli-0.0.11-py3-none-any.whl (11 kB)
# Downloading fastapi_cloud_cli-0.1.5-py3-none-any.whl (18 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich_toolkit-0.15.1-py3-none-any.whl (29 kB)
# Downloading rignore-0.6.4-cp312-cp312-macosx_11_0_arm64.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.7/819.7 kB 169.1 kB/s  0:00:04eta 0:00:01
# Downloading sentry_sdk-2.37.1-py2.py3-none-any.whl (368 kB)
# Downloading typer-0.17.4-py3-none-any.whl (46 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading httptools-0.6.4-cp312-cp312-macosx_11_0_arm64.whl (104 kB)
# Downloading uvloop-0.21.0-cp312-cp312-macosx_10_13_universal2.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 229.8 kB/s  0:00:06 eta 0:00:01
# Downloading watchfiles-1.1.0-cp312-cp312-macosx_11_0_arm64.whl (394 kB)
# Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Installing collected packages: websockets, uvloop, uvicorn, typing-extensions, sentry-sdk, rignore, python-multipart, jinja2, httptools, dnspython, watchfiles, starlette, email-validator, typer, rich-toolkit, fastapi-cli, fastapi, fastapi-cloud-cli
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0━━━━━━━━━━━  3/18 [typing-extensions]
#   Attempting uninstall: sentry-sdk━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/18 [typing-extensions]
#     Found existing installation: sentry-sdk 2.18.0━━━━━━━━━━━━━━━━  4/18 [sentry-sdk]ns]
#     Uninstalling sentry-sdk-2.18.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/18 [sentry-sdk]
#       Successfully uninstalled sentry-sdk-2.18.0━━━━━━━━━━━━━━  4/18 [sentry-sdk]
#   Attempting uninstall: jinja2━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/18 [sentry-sdk]
#     Found existing installation: Jinja2 3.1.4━━━━━━━━━━━━━━━━━  4/18 [sentry-sdk]
#     Uninstalling Jinja2-3.1.4:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/18 [sentry-sdk]
#       Successfully uninstalled Jinja2-3.1.4━━━━━━━━━━━━━━━━━━━  4/18 [sentry-sdk]
#   Attempting uninstall: typer━━━━━╸━━━━━━━━━━━━━ 12/18 [email-validator]
#     Found existing installation: typer 0.9.0━━━━━━━━━━━━━ 12/18 [email-validator]
#     Uninstalling typer-0.9.0:━╸━━━━━━━━━━━━━ 12/18 [email-validator]
#       Successfully uninstalled typer-0.9.00m━━━━━━━━━━━━━ 12/18 [email-validator]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [fastapi-cloud-cli]l-validator]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.0 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.32.0 which is incompatible.
# Successfully installed dnspython-2.8.0 email-validator-2.3.0 fastapi-0.116.1 fastapi-cli-0.0.11 fastapi-cloud-cli-0.1.5 httptools-0.6.4 jinja2-3.1.6 python-multipart-0.0.20 rich-toolkit-0.15.1 rignore-0.6.4 sentry-sdk-2.37.1 starlette-0.47.3 typer-0.17.4 typing-extensions-4.15.0 uvicorn-0.35.0 uvloop-0.21.0 watchfiles-1.1.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install fastapi uvicorn pydantic joblib
# Out:
# Requirement already satisfied: fastapi in /opt/anaconda3/lib/python3.12/site-packages (0.116.1)
# Requirement already satisfied: uvicorn in /opt/anaconda3/lib/python3.12/site-packages (0.35.0)
# Requirement already satisfied: pydantic in /opt/anaconda3/lib/python3.12/site-packages (2.8.2)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn) (0.14.0)

# %%
# %%writefile app.py
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
from pydantic import BaseModel
import joblib
import numpy as np

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # or ["http://localhost:3000"] for more security
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# Load trained logistic regression model
model = joblib.load("model.pkl")

class LoanRequest(BaseModel):
    Age: float
    Income_Level: float
    Account_Balance: float
    Deposits: float
    Withdrawals: float
    Transfers: float
    International_Transfers: float
    Investments: float
    Loan_Amount: float
    Loan_Term_Months: float

@app.post("/predict")
def predict(data: LoanRequest):
    features = np.array([[
        data.Age,
        data.Income_Level,
        data.Account_Balance,
        data.Deposits,
        data.Withdrawals,
        data.Transfers,
        data.International_Transfers,
        data.Investments,
        data.Loan_Amount,
        data.Loan_Term_Months
    ]])

    prediction = int(model.predict(features)[0])

    reliable = None;
    
    if prediction == 1:
        reliable = False;
    else:
        reliable = True;

    
    return {
        "reliable": reliable,
        "message": "✅ This user could be considered for a loan."
        if reliable
        else "❌ They aren't liable for a loan."
    }
# Out:
# Overwriting app.py

# %%
# !uvicorn app:app --reload --host 0.0.0.0 --port 8000
# Out:
# INFO:     Will watch for changes in these directories: ['/Users/liburn/DataHackathon']
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [21047] using WatchFiles
# INFO:     Started server process [21049]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:54386 - "OPTIONS /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54386 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54403 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54439 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54450 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54459 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54479 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54483 - "POST /predict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54519 - "OPTIONS /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54519 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54529 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54559 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54588 - "POST /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:54610 - "POST /predict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55056 - "OPTIONS /predict HTTP/1.1" 200 OK
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# INFO:     127.0.0.1:55056 - "POST /predict HTTP/1.1" 200 OK
